# %%
! pip install 'git+https://github.com/EleutherAI/lm-evaluation-harness.git'

! pip install torch --index-url https://download.pytorch.org/whl/cu121   # or cpu / cu118 as you wish
! pip install transformers accelerate sentencepiece

# LiteLLM proxy (for Gemini) and Google SDK
! pip install litellm google-generativeai --upgrade
! pip install openai transformers accelerate
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-vhur44lz
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-vhur44lz
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit 29ea6832cd913b055ec1d6962180c773e8a7ac88
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting accelerate>=0.26.0 (from lm_eval==0.4.8)
#   Downloading accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate (from lm_eval==0.4.8)
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.16.0 (from lm_eval==0.4.8)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting jsonlines (from lm_eval==0.4.8)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting numexpr (from lm_eval==0.4.8)
#   Downloading numexpr-2.10.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting peft>=0.2.0 (from lm_eval==0.4.8)
#   Downloading peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.8)
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting pytablewriter (from lm_eval==0.4.8)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.8)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.8)
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting scikit-learn>=0.24.1 (from lm_eval==0.4.8)
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting sqlitedict (from lm_eval==0.4.8)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from lm_eval==0.4.8) (2.7.0)
# Collecting tqdm-multiprocess (from lm_eval==0.4.8)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl.metadata (5.7 kB)
# Collecting transformers>=4.1 (from lm_eval==0.4.8)
#   Downloading transformers-4.52.2-py3-none-any.whl.metadata (40 kB)
# Collecting zstandard (from lm_eval==0.4.8)
#   Downloading zstandard-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting dill (from lm_eval==0.4.8)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting word2number (from lm_eval==0.4.8)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting more_itertools (from lm_eval==0.4.8)
#   Downloading more_itertools-10.7.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate>=0.26.0->lm_eval==0.4.8) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate>=0.26.0->lm_eval==0.4.8) (25.0)
# Requirement already satisfied: psutil in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate>=0.26.0->lm_eval==0.4.8) (7.0.0)
# Requirement already satisfied: pyyaml in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate>=0.26.0->lm_eval==0.4.8) (6.0.2)
# Collecting huggingface-hub>=0.21.0 (from accelerate>=0.26.0->lm_eval==0.4.8)
#   Downloading huggingface_hub-0.31.4-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate>=0.26.0->lm_eval==0.4.8)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from datasets>=2.16.0->lm_eval==0.4.8) (3.18.0)
# Collecting pyarrow>=15.0.0 (from datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading pyarrow-20.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill (from lm_eval==0.4.8)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from datasets>=2.16.0->lm_eval==0.4.8) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from datasets>=2.16.0->lm_eval==0.4.8) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from datasets>=2.16.0->lm_eval==0.4.8) (4.67.1)
# Collecting xxhash (from datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading multidict-6.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8)
#   Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (72 kB)
# Requirement already satisfied: idna>=2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.8) (3.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0->lm_eval==0.4.8) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.8) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.8) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.8) (2025.4.26)
# Collecting absl-py (from rouge-score>=0.0.4->lm_eval==0.4.8)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting nltk (from rouge-score>=0.0.4->lm_eval==0.4.8)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: six>=1.14.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from rouge-score>=0.0.4->lm_eval==0.4.8) (1.17.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.8)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex (from sacrebleu>=1.5.0->lm_eval==0.4.8)
#   Downloading regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting tabulate>=0.8.9 (from sacrebleu>=1.5.0->lm_eval==0.4.8)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.8)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lxml (from sacrebleu>=1.5.0->lm_eval==0.4.8)
#   Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=0.24.1->lm_eval==0.4.8)
#   Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.24.1->lm_eval==0.4.8)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.24.1->lm_eval==0.4.8)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: sympy>=1.13.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (1.14.0)
# Requirement already satisfied: networkx in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (3.4.2)
# Requirement already satisfied: jinja2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=1.8->lm_eval==0.4.8) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from triton==3.3.0->torch>=1.8->lm_eval==0.4.8) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8->lm_eval==0.4.8) (1.3.0)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.1->lm_eval==0.4.8)
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jinja2->torch>=1.8->lm_eval==0.4.8) (3.0.2)
# Collecting click (from nltk->rouge-score>=0.0.4->lm_eval==0.4.8)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.8) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.8) (2025.2)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter->lm_eval==0.4.8)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.8)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.8)
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.8)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.8)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.8)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.8)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading accelerate-1.7.0-py3-none-any.whl (362 kB)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.5 MB/s eta 0:00:00
# Downloading multidict-6.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
# Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
# Downloading huggingface_hub-0.31.4-py3-none-any.whl (489 kB)
# Downloading peft-0.15.2-py3-none-any.whl (411 kB)
# Downloading propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (232 kB)
# Downloading pyarrow-20.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 70.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 36.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 81.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading transformers-4.52.2-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 77.1 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 90.8 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 72.2 MB/s eta 0:00:00
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 81.3 MB/s eta 0:00:00
# Downloading more_itertools-10.7.0-py3-none-any.whl (65 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.4 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading numexpr-2.10.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (398 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Downloading zstandard-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 80.0 MB/s eta 0:00:00
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.8-py3-none-any.whl size=7420306 sha256=0cdf0a0ecac00256d7e456a60aa233e00f95d42a46b418b73fb2818b81254adc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8gtarivj/wheels/14/4f/5c/a21f2eb9ccc91346023767a7fbab39d02217e68c93fc36cf7f
#   DEPRECATION: Building 'rouge-score' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'rouge-score'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24988 sha256=b4254d6a705b86f7e4238037bdeeba6d24ab123734c70014d3342f606473a78d
#   Stored in directory: /home/nivanov/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
#   DEPRECATION: Building 'sqlitedict' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'sqlitedict'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16958 sha256=5a020fcf8e49c47970375a32f2dd88684ef65a2da58b7303784f644f920888cc
#   Stored in directory: /home/nivanov/.cache/pip/wheels/73/63/89/7210274f9b7fb033b8f22671f64c0e0b55083d30c3c046a3ff
#   DEPRECATION: Building 'word2number' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'word2number'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5658 sha256=bc727355a9cb9aa54c7347b9e8dcc29c966c4aafca72498413de10e60317d66a
#   Stored in directory: /home/nivanov/.cache/pip/wheels/cd/ef/ae/073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, zstandard, xxhash, threadpoolctl, tcolorpy, tabulate, scipy, safetensors, regex, pybind11, pyarrow, propcache, portalocker, pathvalidate, numexpr, multidict, more_itertools, lxml, jsonlines, joblib, fsspec, frozenlist, dill, colorama, click, chardet, aiohappyeyeballs, absl-py, yarl, tqdm-multiprocess, scikit-learn, sacrebleu, nltk, multiprocess, mbstrdecoder, huggingface-hub, aiosignal, typepy, tokenizers, rouge-score, aiohttp, transformers, accelerate, peft, datasets, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
#   Attempting uninstall: fsspec━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 20/51 [joblib]]
#     Found existing installation: fsspec 2025.5.08;114m╸━━━━━━━━━━━━━━━━━━━━━━━━ 20/51 [joblib]
#     Uninstalling fsspec-2025.5.0:╸━━━━━━━━━━━━━━━━━━━━━━━━ 20/51 [joblib]
#       Successfully uninstalled fsspec-2025.5.0;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━ 20/51 [joblib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 [lm_eval]1 [lm_eval]1 [DataProperty]ormers]
# Successfully installed DataProperty-1.1.0 absl-py-2.2.2 accelerate-1.7.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 chardet-5.2.0 click-8.2.1 colorama-0.4.6 datasets-3.6.0 dill-0.3.8 evaluate-0.4.3 frozenlist-1.6.0 fsspec-2025.3.0 huggingface-hub-0.31.4 joblib-1.5.0 jsonlines-4.0.0 lm_eval-0.4.8 lxml-5.4.0 mbstrdecoder-1.1.4 more_itertools-10.7.0 multidict-6.4.4 multiprocess-0.70.16 nltk-3.9.1 numexpr-2.10.2 pathvalidate-3.2.3 peft-0.15.2 portalocker-3.1.1 propcache-0.3.1 pyarrow-20.0.0 pybind11-2.13.6 pytablewriter-1.2.1 regex-2024.11.6 rouge-score-0.1.2 sacrebleu-2.5.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.3 sqlitedict-2.1.0 tabledata-1.3.4 tabulate-0.9.0 tcolorpy-0.1.7 threadpoolctl-3.6.0 tokenizers-0.21.1 tqdm-multiprocess-0.0.11 transformers-4.52.2 typepy-1.3.4 word2number-1.1 xxhash-3.5.0 yarl-1.20.0 zstandard-0.23.0
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (2.7.0)
# Requirement already satisfied: filelock in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from triton==3.3.0->torch) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: transformers in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (4.52.2)
# Requirement already satisfied: accelerate in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (1.7.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: filelock in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (0.31.4)
# Requirement already satisfied: numpy>=1.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: psutil in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from accelerate) (2.7.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from triton==3.3.0->torch>=2.0.0->accelerate) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests->transformers) (2025.4.26)
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Collecting litellm
#   Downloading litellm-1.70.2-py3-none-any.whl.metadata (38 kB)
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: aiohttp in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (3.11.18)
# Requirement already satisfied: click in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (8.2.1)
# Requirement already satisfied: httpx>=0.23.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (0.28.1)
# Collecting importlib-metadata>=6.8.0 (from litellm)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (4.23.0)
# Collecting openai<1.76.0,>=1.68.2 (from litellm)
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (2.11.4)
# Collecting python-dotenv>=0.2.0 (from litellm)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting tiktoken>=0.7.0 (from litellm)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from litellm) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.25.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (0.10.0)
# Requirement already satisfied: sniffio in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from openai<1.76.0,>=1.68.2->litellm) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<1.76.0,>=1.68.2->litellm) (3.10)
# Requirement already satisfied: certifi in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from httpx>=0.23.0->litellm) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.4.0)
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai)
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai)
#   Downloading google_api_python_client-2.169.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai)
#   Downloading google_auth-2.40.2-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting protobuf (from google-generativeai)
#   Downloading protobuf-6.31.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.25.0rc1-py3-none-any.whl.metadata (3.0 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf (from google-generativeai)
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core->google-generativeai)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from google-api-core->google-generativeai) (2.32.3)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from tiktoken>=0.7.0->litellm) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from aiohttp->litellm) (1.20.0)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client->google-generativeai)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from tokenizers->litellm) (0.31.4)
# Requirement already satisfied: filelock in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/nivanov/miniconda3/envs/mera/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (6.0.2)
# Downloading litellm-1.70.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 20.2 MB/s eta 0:00:0031m45.0 MB/s eta 0:00:01
# Downloading openai-1.75.0-py3-none-any.whl (646 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 57.8 MB/s eta 0:00:00
# Downloading google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.5 MB/s eta 0:00:00
# Downloading google_api_core-2.25.0rc1-py3-none-any.whl (160 kB)
# Downloading google_auth-2.40.2-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 70.3 MB/s eta 0:00:00
# Downloading grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 85.1 MB/s eta 0:00:00
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading google_api_python_client-2.169.0-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 63.0 MB/s eta 0:00:000:00:01
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: zipp, uritemplate, python-dotenv, pyparsing, pyasn1, protobuf, grpcio, cachetools, tiktoken, rsa, pyasn1-modules, proto-plus, importlib-metadata, httplib2, googleapis-common-protos, openai, grpcio-status, google-auth, litellm, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: openai━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 10/24 [pyasn1-modules]
#     Found existing installation: openai 1.80.0╺━━━━━━━━━━━━━━ 15/24 [openai]n1-modules]
#     Uninstalling openai-1.80.0:━━━━━━━━━━━╺━━━━━━━━━━━━━━ 15/24 [openai]
#       Successfully uninstalled openai-1.80.00m╺━━━━━━━━━━━━━━ 15/24 [openai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [google-generativeai]3/24 [google-generativeai]erativelanguage]
# Successfully installed cachetools-5.5.2 google-ai-generativelanguage-0.6.15 google-api-core-2.25.0rc1 google-api-python-client-2.169.0 google-auth-2.40.2 google-auth-httplib2-0.2.0 google-generativeai-0.8.5 googleapis-common-protos-1.70.0 grpcio-1.71.0 grpcio-status-1.71.0 httplib2-0.22.0 importlib-metadata-8.7.0 litellm-1.70.2 openai-1.75.0 proto-plus-1.26.1 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyparsing-3.2.3 python-dotenv-1.1.0 rsa-4.9.1 tiktoken-0.9.0 uritemplate-4.1.1 zipp-3.21.0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1,2,3"
import json, pathlib, sys
import pandas as pd

# %%
import json
import glob
import pandas as pd

# %%
# -- CONFIGURE THIS: top‐level folder containing one subfolder per model
RESULTS_ROOT = "./my_tasks/results_qwen_2_7b/"
# e.g. RESULTS_ROOT/
#           ├─ gemma__google-gemma-7b/
#           ├─ mistralai__Mistral-7B-Instruct-v0.1/
#           ├─ ... etc

def load_model_df(model_dir):
    # find the .jsonl sample file
    files = glob.glob(os.path.join(model_dir, "*.jsonl"))
    if not files:
        raise FileNotFoundError(f"No .jsonl samples found in {model_dir}")
    # pick the first or use a naming heuristic
    samples_file = sorted(files)[0]
    
    records = []
    with open(samples_file, "r", encoding="utf-8") as f:
        for line in f:
            obj = json.loads(line)
            subset = obj.get("metadata", {}).get("subset", "UNKNOWN")
            acc    = obj.get("result", {}).get("acc", 0.0)
            records.append({"subset": subset, "acc": acc})
    
    df = pd.DataFrame(records)
    agg = (
        df
        .groupby("subset")
        .agg(total=("acc", "size"), correct=("acc", "sum"))
        .reset_index()
    )
    agg["accuracy"] = agg["correct"] / agg["total"]
    return agg

# %%
def main():
    all_results = {}
    # iterate through each model's directory
    for entry in os.listdir(RESULTS_ROOT):
        model_dir = os.path.join(RESULTS_ROOT, entry)
        if not os.path.isdir(model_dir):
            continue
        try:
            df = load_model_df(model_dir)
            model_name = entry.split("__")[1] if "__" in entry else entry
            all_results[model_name] = df
        except Exception as e:
            print(f"⚠️ Skipping {entry}: {e}")

    # Now you have a dict: { model_name: DataFrame }
    # For example, to print each:
    for model, df in all_results.items():
        print(f"\n=== {model} ===")
        print(df.to_string(index=False))

    # Optionally, concatenate all into one big DataFrame:
    combined = (
        pd.concat(
            [df.assign(model=model) for model, df in all_results.items()],
            ignore_index=True
        )
        .pivot(index="subset", columns="model", values="accuracy")
        .fillna(0.0)
    )
    print("\n=== Combined accuracy matrix ===")
    print(combined)

# %%
main()
# Out:
# === Qwen2-7B-Instruct ===
#  subset  total  correct  accuracy
# UNKNOWN   4590      0.0       0.0
#
# === Combined accuracy matrix ===
# model    Qwen2-7B-Instruct
# subset
# UNKNOWN                0.0

# %%
df = pd.read_json(, lines=True)

# %%
jsonl_path = "./my_tasks/agro/results_agro_llama/VityaVitalich__Llama3.1-8b-instruct/samples_agro_mc_2025-05-27T19-58-45.920956.jsonl"

# %%
records = []
with open(jsonl_path, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        subset = obj.get("doc", {}).get("subset", "UNKNOWN")
        acc = obj.get("acc", 0.0)
        records.append({"subset": subset, "acc": acc})

# Create DataFrame and compute metrics
df = pd.DataFrame(records)
grouped = df.groupby("subset").agg(
    total_examples=("acc", "size"),
    correct_predictions=("acc", "sum")
).reset_index()
grouped["accuracy"] = grouped["correct_predictions"] / grouped["total_examples"]

# Compute overall accuracy
total_examples = grouped["total_examples"].sum()
total_correct = grouped["correct_predictions"].sum()
overall_accuracy = total_correct / total_examples if total_examples > 0 else 0.0

# Append overall row using concat
overall_row = pd.DataFrame([{
    "subset": "overall_accuracy",
    "total_examples": total_examples,
    "correct_predictions": total_correct,
    "accuracy": overall_accuracy
}])
result = pd.concat([grouped, overall_row], ignore_index=True)
result['correct_predictions'] = result['correct_predictions'].astype(int)

# %%
result
# Out:
#                                                subset  total_examples  \
# 0                                            Ботаника             227
# 1                         Индустриальная аквакультура             251
# 2   Ихтиопатология: ветеринария, профилактика и оп...             246
# 3                Кормление рыбы и других гидробионтов             259
# 4                     Кормопроизводство и луговодство             270
# 5   Марикультура. Разведение раков, креветок. Иску...             236
# 6                            Мелиоративное земледелие             270
# 7                                      Общая генетика             260
# 8                                    Общее земледелие             274
# 9                                     Основы селекции             259
# 10                                    Растениеводство             336
# 11                      Семеноводство и семеноведение             215
# 12     Системы земледелия на различных агроландшафтах             273
# 13  Технологии возделывания сельскохозяйственных к...             258
# 14                                   overall_accuracy            3634
#
#     correct_predictions  accuracy
# 0                    52  0.229075
# 1                    89  0.354582
# 2                    53  0.215447
# 3                    68  0.262548
# 4                    47  0.174074
# 5                    40  0.169492
# 6                    99  0.366667
# 7                    76  0.292308
# 8                    70  0.255474
# 9                    78  0.301158
# 10                   63  0.187500
# 11                   53  0.246512
# 12                  120  0.439560
# 13                   70  0.271318
# 14                  978  0.269125

# %%
sheet_name="Llama3.1-8b-instruct"
existing_excel = "agro_mc.xlsx"
with pd.ExcelWriter(existing_excel, engine="openpyxl") as writer:
    grouped.to_excel(writer,
                     sheet_name=sheet_name,
                     index=False,
                     float_format="%.4f")

print(f"Saved subset accuracies to '{existing_excel}' on sheet {sheet_name}")
# Out:
# Saved subset accuracies to 'agro_mc.xlsx' on sheet Llama3.1-8b-instruct

# %%
from openpyxl import load_workbook

sheet_name="Llama3.1-8b-instruct"
existing_excel = "agro_mc.xlsx"
book = load_workbook(existing_excel)

with pd.ExcelWriter(existing_excel, engine="openpyxl", mode="a", if_sheet_exists="replace") as writer:

    result.to_excel(
        writer,
        sheet_name=sheet_name,
        index=False,
        float_format="%.4f"
    )

print(f"Saved subset accuracies to '{output_path}' on sheet {sheet_name}")
# Out:
# Saved subset accuracies to 'med_mc.xlsx' on sheet Llama3.1-8b-instruct
